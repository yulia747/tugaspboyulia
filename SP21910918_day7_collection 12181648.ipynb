// %% [markdown]
// ## Java Collection
//
//
// Seperti halnya C++ bahasa pemrograman Java juga mempunyai Struktur Data tersendiri. Berikut ini beberapa bentuk struktur data yang ada di Java :
//
// A. Array Multi Dimensi
//
// B. Array Object
//
// C. List
//
// D. HashSet
//
// E. HashMap
//
// F. HashTable
//
//
// ### A. Array Multi Dimensi
//
// Array multi dimensi artinya array yang memiliki lebih dari satu dimensi. Atau kita bisa sebut, array di dalam array.
// Jumlah dimensinya tidak terbatas, sesuai dengan kebutuhan pengguna.
//
// Berikut ini adalah contoh array dua dimensi:
// ``` javascript
// String[][] Siswa = {
//     {"Lili","08111"},
//     {"Lala","08122"},
//     {"Maya","08133"}
// };
// ```
// Indek *ke-0* pada array kontak berisi array *{"lili","08111"}*.
//
// Indek *ke-1* pada array kontak berisi array *{"lala","08122"}*.
//
// Indek *ke-2* pada array kontak berisi array *{"lulu","08133"}*.
//
// maka secara visualisasi seolah - olah akan terbentuk tabulasi sebagai berikut:
//
//          c0  |    c1
//     r0|"Lili"|"08111"|
//     r1|"Lala"|"08122"|
//     r2|"Maya"|"08133"|
//
//  keterangan : r0..rN  adalah baris dan c0..cN adalah kolom
//
// #### Soal 7.1
//  Implementasikan kode  berikut yang merupakan contoh dan cara mengakses data dari array dua dimensi:
//
// ``` javascript
// //program 7.1
//
//  String[][] Siswa = {
//     {"Lili","08111"},
//     {"Lala","08122"},
//     {"Maya","08133"}
// };
//
// for(int x=0; x < Siswa.length; x++){
//     System.out.println("Nama "+Siswa[x][0]);
//     System.out.println("NIM "+Siswa[x][1]);
// }
// ```

// %%
//program 7.1
String[][] Siswa = {
    {"Lili","08111"},
    {"Lala","08122"},
    {"Maya","08133"}
};

for(int x=0; x < Siswa.length; x++){
    System.out.println("Nama "+Siswa[x][0]);
    System.out.println("NIM "+Siswa[x][1]);
}
// Out:
// Nama Lili
// NIM 08111
// Nama Lala
// NIM 08122
// Nama Maya
// NIM 08133

// %% [markdown]
// #### Soal 7.2
// Terdapat sebuah data tabular Mahasiswa dengan dengan tabel sebagai berikut :
//
//     |  NIM  |  Nama  |IPK|
//     |"08111"|"Dono  "|3.0|
//     |"08113"|"Kasino"|2.7|
//     |"08115"|"Indro "|3.1|
//
// Implementasikan data tabular Mahasiswa diatas dalam sebuah array multi dimensi kedalam *program 7.2*

// %%
//program 7.2

String[][] Mahasiswa = {
    {"08111","Dono","3.0"},
    {"08113","Kasino","2.7"},
    {"08115","Indro","3.1"}
};

for(int x=0; x < Siswa.length; x++){
    System.out.println("NIM "+Mahasiswa[x][0]);
    System.out.println("Nama "+Mahasiswa[x][1]);
    System.out.println("IPK "+Mahasiswa[x][2]);
}
// Out:
// NIM 08111
// Nama Dono
// IPK 3.0
// NIM 08113
// Nama Kasino
// IPK 2.7
// NIM 08115
// Nama Indro
// IPK 3.1

// %% [markdown]
// ### B. Objek Array
//
// Pada pembahasan sebelumnya, kita mengetahui cara untuk membuat array dengan elemen dari tipe data primitif. Seperti halnya pada tipe data primitif, array juga dapat memegang objek-objek pada pemrograman Java.
// Contoh berikut ini adalah untuk membuat array dari objek, misalnya dari class PersegiPanjang, anda dapat melakukannya dengan:
//
// ``` javascript
// PersegiPanjang PersegiPanjangArray = new PersegiPanjang[10];
// ```
//
// Pernyataan di atas akan membuat array yang dapat memegang referensi dari sepuluh objek dari class PersegiPanjang. Namun, pernyataan ini tidak membuat objek dari class itu sendiri. Objek-objek ini harus dibuat secara terpisah menggunakan konstruktor dari class PersegiPanjang.
//
// *PersegiPanjang PersegiPanjangArray* akan memiliki sepuluh ruang memori dimana sepuluh objek dari class itu akan disimpan.
//
//  ### Soal 7.4
//   Implementasikan kode Program 7.4 dibawah ini, lakukan juga inisisiali untuk element element dari array yang dibutuhkan
//
// ------------------------------------------------
// ``` javascript
// //Program 7.3
// class PersegiPanjang{
//     int panjang;
//     int lebar;
//     int luas;
//
//     void setPanjang(int panjang) {
//         this.panjang = panjang;
//     }
//
//     void setLebar(int lebar) {
//         this.lebar = lebar;
//     }
//     int getLuas(){
//       luas = panjang * lebar;
//       return luas;
//     }
// }
// ```
// ------------------------------------------------
// ``` javascript
//         PersegiPanjang [] myArray = new PersegiPanjang [3];
//
//         myArray[0] = new PersegiPanjang();
//         myArray[0].setPanjang(10);
//         myArray[0].setLebar(5);
//
//         System.out.println("Luas Element ke 0 "+ myArray[0].getLuas());
//
//         /*
//          Lakukan inisialisasi Objek PersegiPanjang elemen ke 2 dan ke 3 disini
//         */
//
//
//         for (int i = 0; i < myArray.length; i++) {
//             System.out.println("Luas Element ke "+i+" "+ myArray[i].getLuas());
//
//         }
// ```
//  ------------------------------------------------
// #### Soal 7.4
// Lakukan eksekusi dari kode diatas dan amanti hasilnya

// %%
//Program 7.4

class PersegiPanjang{
    int panjang;
    int lebar;
    int luas;

    void setPanjang(int panjang) { 
        this.panjang = panjang;
    } 

    void setLebar(int lebar) { 
        this.lebar = lebar; 
    } 
    int getLuas(){
      luas = panjang * lebar;
      return luas;  
    }
}

PersegiPanjang [] myArray = new PersegiPanjang [3];

        myArray[0] = new PersegiPanjang();
        myArray[0].setPanjang(10); 
        myArray[0].setLebar(5);

        System.out.println("Luas Element ke 0 "+ myArray[0].getLuas());

        /*
         Lakukan inisialisasi Objek PersegiPanjang elemen ke 2 dan ke 3 disini 
        */
        myArray[1] = new PersegiPanjang();
        myArray[1].setPanjang(10); 
        myArray[1].setLebar(10);

        myArray[2] = new PersegiPanjang();
        myArray[2].setPanjang(10); 
        myArray[2].setLebar(20);

        for (int i = 0; i < myArray.length; i++) {
            System.out.println("Luas Element ke "+i+" "+ myArray[i].getLuas());

        }
// Out:
// Luas Element ke 0 50
// Luas Element ke 0 50
// Luas Element ke 1 100
// Luas Element ke 2 200

// %% [markdown]
// #### Soal 7.5
// Implementasikan kasus UTS anda kedalam sebuah object array seperti halnya *program 7.5*

// %%
//Program 7.5
class Tabung{
    double tinggi,volume,LuasAlas,LuasSelimut,LuasPermukaan ,r; 
    double phi = 3.14;
    
    void setR(double r){
        this.r = r;
    }
    
    void setPhi(double phi){
        this.phi = 3.14;
    }
    
    void setTinggi(double tinggi){
        this.tinggi = tinggi;
    }
    
    double getVolume(){
        volume = phi * r * r * tinggi;
        return volume;
    }
    
    double getLuasAlas(){
        LuasAlas = phi * r * r;
        return LuasAlas;
    }
    
    double getLuasSelimut(){
        LuasSelimut = 2 * phi * r * tinggi;
        return LuasSelimut;
    }
    
    double getLuasPermukaan(){
        LuasPermukaan = 2 * phi *r *(r + tinggi);
        return LuasPermukaan;
    }
}

// %%
Tabung [] myArray = new Tabung[4];

    myArray[0] = new Tabung();
    myArray[0].setR(10);
    myArray[0].setTinggi(20);

    myArray[1] = new Tabung();
    myArray[1].setR(7);
    myArray[1].setTinggi(10);

    myArray[2] = new Tabung();
    myArray[2].setR(21);
    myArray[2].setTinggi(35);

    myArray[3] = new Tabung();
    myArray[3].setR(14);
    myArray[3].setTinggi(20);

for(int i = 0; i < myArray.length; i++){
    System.out.println("Volume Tabung ke - "+i+" adalah "+myArray[i].getVolume());
    System.out.println("Luas Alas Tabung ke - "+i+" adalah "+myArray[i].getLuasAlas());
    System.out.println("Luas Selimut Tabung ke - "+i+" adalah "+myArray[i].getLuasSelimut());
    System.out.println("Luas Permukaan Tabung ke - "+i+" adalah "+myArray[i].getLuasPermukaan());
}
// Out:
// Volume Tabung ke - 0 adalah 6280.0
// Luas Alas Tabung ke - 0 adalah 314.0
// Luas Selimut Tabung ke - 0 adalah 1256.0
// Luas Permukaan Tabung ke - 0 adalah 1884.0000000000002
// Volume Tabung ke - 1 adalah 1538.6000000000001
// Luas Alas Tabung ke - 1 adalah 153.86
// Luas Selimut Tabung ke - 1 adalah 439.6
// Luas Permukaan Tabung ke - 1 adalah 747.32
// Volume Tabung ke - 2 adalah 48465.9
// Luas Alas Tabung ke - 2 adalah 1384.74
// Luas Selimut Tabung ke - 2 adalah 4615.8
// Luas Permukaan Tabung ke - 2 adalah 7385.28
// Volume Tabung ke - 3 adalah 12308.800000000001
// Luas Alas Tabung ke - 3 adalah 615.44
// Luas Selimut Tabung ke - 3 adalah 1758.4
// Luas Permukaan Tabung ke - 3 adalah 2989.28

// %% [markdown]
// ## C. List
//
// Array yang kita bahas di atas sebenarnya memiliki beberapa kekurangan yang utama yaitu :
//
//     Tidak mampu menyimpan data dengan tipe yang berbeda.
//     Ukurannya tidak dinamis.
//
// Interface **List** dapat diimplementasikan oleh kedalam bentuk
//
// * ArrayList
// * Vector
// * LinkedList
// * Stack.
//
// Untuk membuat instance antarmuka *List*, kita harus mendefiniskan instan objek sebelum menggunakannya :
//
// ``` javascript
//
//  //Implementasi List dalam sebuah array
//  List a = new ArrayList();
//
//  //Implementasi List dalam sebuah Vector
//  List c = new Vector();
//
//  //Implementasi List dalam sebuah Linked List
//  List b = new LinkedList();
//
//  //Implementasi List dalam sebuah Stack (Tumpukan)
//  List d = new Stack();
// ```
//
// > “Pada pokok bahasan berikut kita tidak akan membahasa tentang *Stack()* dan *LinkedList()*, karena dua bentuk tersebut
// > sudah dibahas pada materi kuliah Struktur Data”
//
// ### C.1 ArrayList
//
// Array list merupakan sebuah class yang memungkinkan kita membuat sebuah objek untuk menampung apapun.
//
// Untuk menggunakan Array List, kita harus mengimpornya terlebih dahulu.
// ``` javascript
// import java.util.ArrayList;
// ```
// Setelah itu, baru kita bisa membuat sebuah objek Array List seperti ini:
//
// ``` javascript
//  ArrayList al = new ArrayList();
// ```
// Contoh Penggunaan ArrayList()
//
// ``` javascript
//         //Program 7.6
//         import java.util.ArrayList;
//
//         ArrayList kantongAjaib = new ArrayList();
//
//         // Mengisi kantong ajaib dengan 5 benda
//         kantongAjaib.add("Senter Pembesar");
//         kantongAjaib.add(532);
//         kantongAjaib.add("tikus");
//         kantongAjaib.add(1231234.132);
//         kantongAjaib.add(true);
//
//         // menghapus tikus dari kantong ajaib
//         kantongAjaib.remove("tikus");
//
//         // Menampilkan isi kantong ajaib
//         System.out.println(kantongAjaib);
//
//         // menampilkan banyak isi kantong ajaib
//         System.out.println("Kantong ajaib berisi "+ kantongAjaib.size() +" item");
//
// ```
//
// #### Soal 7.6
// Lakukan eksekusi dari kode diatas dan amati hasilnya

// %%
//program 7.6

        import java.util.ArrayList;

        ArrayList kantongAjaib = new ArrayList();

        // Mengisi kantong ajaib dengan 5 benda
        kantongAjaib.add("Senter Pembesar");
        kantongAjaib.add(532);
        kantongAjaib.add("tikus");
        kantongAjaib.add(1231234.132);
        kantongAjaib.add(true);

        // menghapus tikus dari kantong ajaib
        kantongAjaib.remove("tikus");

        // Menampilkan isi kantong ajaib
        System.out.println(kantongAjaib);

        // menampilkan banyak isi kantong ajaib
        System.out.println("Kantong ajaib berisi "+ kantongAjaib.size() +" item");
// Out:
// [Senter Pembesar, 532, 1231234.132, true]
// Kantong ajaib berisi 4 item

// %% [markdown]
// Karena array list (kantongAjaib) merupakan sebuah objek yang terbuat dari class Array List, maka dia punya method (fungsi) untuk melakukan sesuatu.
//
// Fungsi *add()* untuk menambahkan sesuatu ke dalam *Array List;*
//
// Fungsi *remove()* untuk menghapus sesuatu ke dalam *Array List;*
//
// Fungsi *size()* untuk mengambil ukuran *Array List;*
//
// Fungsi *get(id)* untuk mengambil item dalam Array List berdasarkan id atau indeks tertentu dan masih banyak fungsi yang lainnya.

// %% [markdown]
// ## C.2 HashMap
// HashMap kadang sering digunakan dalam pembuatan aplikasi Java. Karena itu, HashMap penting untuk kita ketahui.
//
// *Class HashMap* merupakan class turunan dari *class AbstractMap* dan implementasi dari *interface Map*.
//
// *HashMap* adalah sebuah class yang berisi sekumpulan pasangan nilai *(value)* dan kunci *(key)*.
//
// Nilai bisa dalam bentuk *string, integer, boolean, float, double,* dan *object*. Sedangkan untuk key biasanya dalam bentuk *string* dan *integer*.
//
// HashMap bisa dibilang seperti Array asosiatif dalam Java.
//
// Perhatikan contoh berikut ini
//
//        key  |    value
//     |"nama "|"STMIK EL Rahma"
//     |"url  "|"http://www.stmikelrahma.ac.id"
//     |"email"|"info@stmikelrahma.ac.id"
//
// Tabel di atas terdiri dari pasangan key dan value, seperti inilah isi dari class atau objek HashMap.
//
// ### Cara Membuat HashMap
// Sebelum bisa menggunakan *HashMap*, kita harus mengimpornya terlebih dahulu:
// ``` javascript
// import java.util.HashMap;
// ```
// Setelah itu baru kita bisa menggunakannya.
//
// Nah!, untuk menggunakan *HashMap*, kita harus membuat objeknya terlebih dahulu. Objek dari Hashmap dapat dibuat dengan kata kunci **new**.
//
// Namun, ada sedikit tambahan untuk menentukan tipe data untuk key dan value yang akan disimpan.
//
// **syntax pendifinisian HasMap**
//
// ``` javascript
// HashMap<Key Value> objectname = new HashMap<Key Value>
// ```
//
// **Contoh**
//
// ``` javascript
// HashMap<Integer, String> hari = new HashMap<Integer,String>
// ```
//
// Pada contoh di atas, kita membuat objek *HashMap* bernama *hari*. Objek ini dapat kita gunakan untuk menyimpan koleksi data.
//
// Tipe data yang digunakan untuk key adalah *Integer* dan value adalah *String*.
//
// Artinya: key harus bertipe *Integer* dan nilai yang tersimpan harus dalam bertipe *String*
//
// ### Mengisi Nilai ke HashMap
//
// Tadi kita sudah membuat objek hashmap bernama *hari* dengan tipe data:
//
//  **K (key):** Integer
//
//  **V (value):** String
//
// Untuk mengisi nilai ke objek *hari*, kita dapat menggunakan method put seperti ini:
//
// ``` javascript
// hari.put(1, "Minggu");
// hari.put(2, "Senin");
// hari.put(3, "Selasa");
// hari.put(4, "Rabu");
// hari.put(5, "Kamis");
// hari.put(6, "Jum'at");
// hari.put(7, "Sabtu");
// ```
//
// Objek HashMap *hari* berisi nama-nama hari dengan key 1–7.
//
// ``` javascript
// import java.util.HashMap;
//
//         //Program 7.7
//
//         // membuat objek hashmap
//         HashMap<Integer, String> hari = new HashMap<Integer,String>();
//
//         // mengisi nilai ke objek days
//         hari.put(1, "Minggu");
//         hari.put(2, "Senin");
//         hari.put(3, "Selasa");
//         hari.put(4, "Rabu");
//         hari.put(5, "Kamis");
//         hari.put(6, "Jum'at");
//         hari.put(7, "Sabtu");
//
//         // mencetak semua isi dari objek days
//         System.out.println("Isi objek days: " + hari);
// ```
// #### Soal 7.7
// Lakukan eksekusi dari kode diatas dan amati hasilnya

// %%
//program 7.7
// membuat objek hashmap
        HashMap<Integer, String> hari = new HashMap<Integer,String>();

        // mengisi nilai ke objek days
        hari.put(1, "Minggu");
        hari.put(2, "Senin");
        hari.put(3, "Selasa");
        hari.put(4, "Rabu");
        hari.put(5, "Kamis");
        hari.put(6, "Jum'at");
        hari.put(7, "Sabtu");

        // mencetak semua isi dari objek days
        System.out.println("Isi objek days: " + hari);
// Out:
// Isi objek days: {1=Minggu, 2=Senin, 3=Selasa, 4=Rabu, 5=Kamis, 6=Jum'at, 7=Sabtu}

// %% [markdown]
// ### Mengambil Nilai dari HashMap
//
// Untuk mengambil nilai dari HashMap, kita bisa menggunakan method get() dengan parameter kuncinya.
//
// ``` javascript
// // mengambil hari senin
// harihari.get(2)
// ```
//
// Kenapa di sana kita isi parameternya 2?
//
// Jawabannya karena kita ingin mengambil nilai senin dan nilai tersebut telah diasosiasikan pada objek HashMap dengan key 2.
//
// Contoh kode lengkap:
//
// ``` javascript
//         //program 7.8
//         import java.util.HashMap;
//
//         // membuat objek hashmap
//         HashMap<Integer, String> harihari = new HashMap<Integer,String>();
//
//         // mengisi nilai ke objek hari
//         harihari.put(1, "Minggu");
//         harihari.put(2, "Senin");
//         harihari.put(3, "Selasa");
//         harihari.put(4, "Rabu");
//         harihari.put(5, "Kamis");
//         harihari.put(6, "Jum'at");
//         harihari.put(7, "Sabtu");
//
//         // mencetak semua isi dari objek hari
//         System.out.println("Isi objek days: " + harihari);
//         // mengambil hari senin
//         System.out.println("Hari kedua: " + harihari.get(2));
// ```
//
// #### Soal 7.8
// Lakukan eksekusi dari kode diatas dan amati hasilnya

// %%
//program 7.8
import java.util.HashMap;

        // membuat objek hashmap
        HashMap<Integer, String> harihari = new HashMap<Integer,String>();

        // mengisi nilai ke objek hari
        harihari.put(1, "Minggu");
        harihari.put(2, "Senin");
        harihari.put(3, "Selasa");
        harihari.put(4, "Rabu");
        harihari.put(5, "Kamis");
        harihari.put(6, "Jum'at");
        harihari.put(7, "Sabtu");

        // mencetak semua isi dari objek hari
        System.out.println("Isi objek days: " + harihari);
        // mengambil hari senin
        System.out.println("Hari kedua: " + harihari.get(2));
// Out:
// Isi objek days: {1=Minggu, 2=Senin, 3=Selasa, 4=Rabu, 5=Kamis, 6=Jum'at, 7=Sabtu}
// Hari kedua: Senin

// %% [markdown]
// ### Menghapus Nilai dari HashMap
// Ada dua method yang dapat digunakan untuk menghapus nilai dari HashMap:
//
//  *remove()* menghapus salah satu nilai;
//
//  *clear()* menghapus semua nilai;
//
//
// Program menghapus kompunen:
//
// ``` javascript
//
//         import java.util.HashMap;
//
//         //Program 7.9
//
//         // membuat objek hashmap
//         HashMap<Integer, String> days = new HashMap<Integer,String>();
//
//         // mengisi nilai ke objek days
//         days.put(1, "Minggu");
//         days.put(2, "Senin");
//         days.put(3, "Selasa");
//         days.put(4, "Rabu");
//         days.put(5, "Kamis");
//         days.put(6, "Jum'at");
//         days.put(7, "Sabtu");
//
//         // mencetak semua isi dari objek days
//         System.out.println("Isi objek days: " + days);
//         System.out.println("Hari kedua: " + days.get(2));
//
//         // menghapus malam minggu <-- jomblo detected :D
//         days.remove(1);
//         System.out.println("Isi objek days: " + days);
//
//         // menghapus semua hari <-- oh tidak kiamat donk!
//         days.clear();
//         System.out.println("Isi objek days: " + days);
//
// ```
// #### Soal 7.9
// Lakukan eksekusi dari kode diatas dan amati hasilnya

// %%
//program 7.9
 import java.util.HashMap;
// membuat objek hashmap
        HashMap<Integer, String> days = new HashMap<Integer,String>();

        // mengisi nilai ke objek days
        days.put(1, "Minggu");
        days.put(2, "Senin");
        days.put(3, "Selasa");
        days.put(4, "Rabu");
        days.put(5, "Kamis");
        days.put(6, "Jum'at");
        days.put(7, "Sabtu");

        // mencetak semua isi dari objek days
        System.out.println("Isi objek days: " + days);
        System.out.println("Hari kedua: " + days.get(2));

        // menghapus malam minggu <-- jomblo detected :D
        days.remove(1);
        System.out.println("Isi objek days: " + days);

        // menghapus semua hari <-- oh tidak kiamat donk!
        days.clear();
        System.out.println("Isi objek days: " + days);
// Out:
// Isi objek days: {1=Minggu, 2=Senin, 3=Selasa, 4=Rabu, 5=Kamis, 6=Jum'at, 7=Sabtu}
// Hari kedua: Senin
// Isi objek days: {2=Senin, 3=Selasa, 4=Rabu, 5=Kamis, 6=Jum'at, 7=Sabtu}
// Isi objek days: {}

// %% [markdown]
// ### Mengubah Nilai dan Kunci dari HashMap
// Ada dua method yang dapat digunakan untuk mengubah nilai di dalam HashMap:
//
// 1 Method *put()*
//
// 2 Method *replace()*
//
// Apa bedanya?
//
// Keduanya sama-sama bisa digunakan untuk mengubah nilai berikut ini perbedaan
//
// untuk method *replace()* nilai yang akan diubah harus sudah ada di dalam HashMap.
//
// Sedangkan untuk method *put()*, dia akan menambahkan yang baru apabila belum ada di dalam HashMap.
//
// ``` javascript
//
// import java.util.HashMap;
//
//         //program 7.10
//
//         // membuat objek hashmap
//         HashMap<Integer, String> days = new HashMap<Integer,String>();
//
//         // mengisi nilai ke objek days
//         days.put(1, "Minggu");
//         days.put(2, "Senin");
//         days.put(3, "Selasa");
//         days.put(4, "Rabu");
//         days.put(5, "Kamis");
//         days.put(6, "Jum'at");
//         days.put(7, "Sabtu");
//
//         // mengubah hari menggu menjadi hari ahad
//         days.put(1, "Ahad");
//
//         // mengubah hari rabu menjadi rabo
//         days.replace(4, "Rabo");
//
//         // mencetak semua isi dari objek days
//         System.out.println("Isi objek days: " + days);
//
//  ```
//  #### Soal 7.10
// Lakukan eksekusi dari kode diatas dan amati hasilnya

// %%
//program 7.10
import java.util.HashMap;

        //program 7.10

        // membuat objek hashmap
        HashMap<Integer, String> days = new HashMap<Integer,String>();

        // mengisi nilai ke objek days
        days.put(1, "Minggu");
        days.put(2, "Senin");
        days.put(3, "Selasa");
        days.put(4, "Rabu");
        days.put(5, "Kamis");
        days.put(6, "Jum'at");
        days.put(7, "Sabtu");

        // mengubah hari menggu menjadi hari ahad
        days.put(1, "Ahad");

        // mengubah hari rabu menjadi rabo
        days.replace(4, "Rabo");

        // mencetak semua isi dari objek days
        System.out.println("Isi objek days: " + days);
// Out:
// Isi objek days: {1=Ahad, 2=Senin, 3=Selasa, 4=Rabo, 5=Kamis, 6=Jum'at, 7=Sabtu}

// %% [markdown]
// ### Objek dengan HashMap
//
// Program ini terdiri dari dua aplikasi, yaitu: class Buku dan implementasi BukuHashMap.
//
// Pada program ini, kamu akan menemukan contoh HashMap yang berisi sekumpulan objek.
//
// Berikut ini isi class Buku:
//
// ``` javascript
//
// //program 7.11
// public class Buku {
//
//     private String title;
//     private String author;
//
//     public Buku(String title, String author) {
//         this.title = title;
//         this.author = author;
//     }
//
//     public String getTitle() {
//         return title;
//     }
//
//     public void setTitle(String title) {
//         this.title = title;
//     }
//
//     public String getAuthor() {
//         return author;
//     }
//
//     public void setAuthor(String author) {
//         this.author = author;
//     }
//
// }
//
// ```
// Berikut ini implementasi  *BukuHashMap* dalam *program 7.12*
//
//
// ``` javascript
//
// // program 7.12
//
// import java.util.HashMap;
// import java.util.Map;
//
//         // membuat objek hashmap
//         HashMap<String, Buku> books = new HashMap<String, Buku>();
//
//         // membuat objek buku
//         Buku bukuJava = new Buku("Tutorial Java", "Petani Kode");
//         Buku bukuKotlin = new Buku("Pemrograman Kotlin", "Petani Kode");
//         Buku bukuAndroid = new Buku("Pemrograman Android", "Petani Kode");
//
//         // mengisi objek hashmap dengan objek buku
//         books.put("java", bukuJava);
//         books.put("kotlin", bukuKotlin);
//         books.put("android", bukuAndroid);
//
//         // cetak semua buku
//         for(Map.Entry b: books.entrySet()){
//             Buku buku = (Buku) b.getValue();
//             System.out.println(b.getKey() + ": "+ buku.getTitle());
//         }
//
//
// ```
//
// Silahkan coba compile sendiri dan pahami maksud dari kode program di atas.

// %%
//program 7.11
public class Buku {

    private String title;
    private String author;

    public Buku(String title, String author) {
        this.title = title;
        this.author = author;
    }

    public String getTitle() {
        return title;
    }

    public void setTitle(String title) {
        this.title = title;
    }

    public String getAuthor() {
        return author;
    }

    public void setAuthor(String author) {
        this.author = author;
    }

}

// %%
// program 7.12
import java.util.HashMap;
import java.util.Map;

        // membuat objek hashmap
        HashMap<String, Buku> books = new HashMap<String, Buku>();

        // membuat objek buku
        Buku bukuJava = new Buku("Tutorial Java", "Petani Kode");
        Buku bukuKotlin = new Buku("Pemrograman Kotlin", "Petani Kode");
        Buku bukuAndroid = new Buku("Pemrograman Android", "Petani Kode");

        // mengisi objek hashmap dengan objek buku
        books.put("java", bukuJava);
        books.put("kotlin", bukuKotlin);
        books.put("android", bukuAndroid);

        // cetak semua buku
        for(Map.Entry b: books.entrySet()){
            Buku buku = (Buku) b.getValue();
            System.out.println(b.getKey() + ": "+ buku.getTitle());
        }
// Out:
// java: Tutorial Java
// android: Pemrograman Android
// kotlin: Pemrograman Kotlin

// %% [markdown]
// #### Soal 7.6
// Implementasikan kasus UTS anda kedalam sebuah object hasmap seperti halnya *program 7.11* dan *program 7.12*
// * aplikasi harus bisa melakukan operasi penambahan
// * aplikasi harus bisa me lakukan operasi penghapusan
// dari hasmap objek yang anda buat

// %%
//program 7.13
// hashmap kasus menambah dan menghapus volume tabung
        HashMap<Integer, Double> volume = new HashMap<Integer,Double>();

        // mengisi nilai ke objek days
        volume.put(1, 20.5);
        volume.put(2, 354.5);
        volume.put(3, 25.255);
        volume.put(4, 70.1);
        

        // mencetak semua isi dari objek volume
        System.out.println("Isi objek volume: " + volume);
        
        //menampilkan volume kedua
        System.out.println("Volume kedua: " + volume.get(2));
        
        //menghapus volume ke1
        volume.remove(1);
        System.out.println("Isi objek volume: " + volume);
        
        // mengubah isi volume 2 
        volume.put(2, 556.7);
        System.out.println("Isi objek volume: " + volume);
        
        // menghapus semua volume
        volume.clear();
        System.out.println("Isi objek volume: " + volume);
// Out:
// Isi objek volume: {1=20.5, 2=354.5, 3=25.255, 4=70.1}
// Volume kedua: 354.5
// Isi objek volume: {2=354.5, 3=25.255, 4=70.1}
// Isi objek volume: {2=556.7, 3=25.255, 4=70.1}
// Isi objek volume: {}

// %% [markdown]
// ## C.4 HashTable
//
// Hastable mempunyai kemiripan dengan HasMap perbedeaanya adalah memungkinkan/memperbolehkan duplikasi dari elemen barisnya sedangkang HashTable tiap barisnya harus unik atau tidak memperbolehkan terjadinya duplicate values

// %% [markdown]
// ## C.5 Data Frame
// pokok bahasan tentang Data Frame akan dibahas pada pokok bahasan tersendiri
